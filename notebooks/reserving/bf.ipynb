# %%
import chainladder as cl

# %%
auto = cl.load_sample("auto")

# %%
auto.iloc[1]['paid']
# Out:
#            12        24        36        48        60        72        84        96        108       120
# 2000  101125.0  209921.0  266618.0  305107.0  327850.0  340669.0  348430.0  351193.0  353353.0  353584.0
# 2001  102541.0  203213.0  260677.0  303182.0  328932.0  340948.0  347333.0  349813.0  350523.0       NaN
# 2002  114932.0  227704.0  298120.0  345542.0  367760.0  377999.0  383611.0  385224.0       NaN       NaN
# 2003  114452.0  227761.0  301072.0  340669.0  359979.0  369248.0  373325.0       NaN       NaN       NaN
# 2004  115597.0  243611.0  315215.0  354490.0  372376.0  382738.0       NaN       NaN       NaN       NaN
# 2005  127760.0  259416.0  326975.0  365780.0  386725.0       NaN       NaN       NaN       NaN       NaN
# 2006  135616.0  262294.0  327086.0  367357.0       NaN       NaN       NaN       NaN       NaN       NaN
# 2007  127177.0  244249.0  317972.0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ...

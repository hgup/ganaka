# %%
import ganaka as gn
import chainladder as cl

# %%
gn.ReservingSession
# Out:
# ganaka.engine.ReservingSession

# %%
import pandas as pd

# %%
a = pd.DataFrame([[1,2],[3,4],[5,6]])
a
# Out:
#    0  1
# 0  1  2
# 1  3  4
# 2  5  6

# %%
renamed = a.rename(columns={0: 'hi',1:'tata'})
exclude = ['tata']
renamed[exclude]
# Out:
#    tata
# 0     2
# 1     4
# 2     6
